# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
pok = pd.read_csv('./data/pokemon.csv', usecols=['Name'], squeeze=True)
pok
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
len(pok)
# Out:
# 800

# %%
min(pok)
# Out:
# 'Abomasnow'

# %%
max(pok)
# Out:
# 'Zygarde50% Forme'

# %%
sorted(pok.head())
# Out:
# ['Bulbasaur', 'Charmander', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur']

# %%
list(pok.tail())
dict(pok.tail())
# Out:
# {795: 'Diancie',
#  796: 'DiancieMega Diancie',
#  797: 'HoopaHoopa Confined',
#  798: 'HoopaHoopa Unbound',
#  799: 'Volcanion'}

# %%
pok.name
# Out:
# 'Name'

# %% [markdown]
# ## Exercise 8

# %%
survey = pd.read_csv('./data/StackOverflowDeveloperSurvey.csv', usecols=['Salary'], squeeze=True).dropna()
survey.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary, dtype: float64

# %%
print(len(survey))
print(min(survey))
print(max(survey))
# Out:
# 12891
# 0.0
# 197000.0

# %%
list(survey.head())
# Out:
# [113750.0, 100000.0, 130000.0, 82500.0, 100764.0]

# %%
dict(survey.head())
# Out:
# {2: 113750.0, 14: 100000.0, 17: 130000.0, 18: 82500.0, 22: 100764.0}

# %%
listSalarySorted = sorted(survey, reverse=True)
listSalarySorted
# Out:
# [197000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  194000.0,
#  193750.0,
#  193000.0,
#  192000.0,
#  192000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  188000.0,
#  187500.0,
#  187200.0,
#  187000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  184000.0,
#  182000.0,
#  181818.181818182,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  178000.0,
#  178000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
# ...

# %%
listSalarySorted[:5]
# Out:
# [197000.0, 195000.0, 195000.0, 195000.0, 195000.0]

# %%
survey.name = "Salary of a person"

# %%
survey.head()
# Out:
# 2     113750.0
# 14    100000.0
# 17    130000.0
# 18     82500.0
# 22    100764.0
# Name: Salary of a person, dtype: float64
