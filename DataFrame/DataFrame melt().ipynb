# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import time

# %%
df = pd.read_csv('../data/marathon_results_2016.csv', index_col='Bib', usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])

# %%
df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
df.head()
# Out:
#      Age M/F         City State Country            Half             40K  \
# Bib
# 5     21   M  Addis Ababa   NaN     ETH 0 days 01:06:45 0 days 02:05:59
# 1     26   M         Ambo   NaN     ETH 0 days 01:06:46 0 days 02:05:59
# 6     31   M  Addis Ababa   NaN     ETH 0 days 01:06:44 0 days 02:06:47
# 11    33   M       Kitale   NaN     KEN 0 days 01:06:46 0 days 02:06:47
# 14    23   M      Eldoret   NaN     KEN 0 days 01:06:46 0 days 02:08:11
#
#         Pace  TotalSeconds  HalfSeconds
# Bib
# 5    0:05:04        7559.0       4005.0
# 1    0:05:06        7559.0       4006.0
# 6    0:05:07        7607.0       4004.0
# 11   0:05:07        7607.0       4006.0
# 14   0:05:11        7691.0       4006.0

# %%
df = df.pivot_table(index="Age",columns="M/F",values="TotalSeconds").head()
df.head()
# Out:
# M/F             F             M
# Age
# 18   16050.666667  14554.615385
# 19   15351.958333  12156.529412
# 20   13835.931818  12111.100000
# 21   14681.027027  12408.360465
# 22   14366.421053  11872.666667

# %%
df.reset_index(inplace=True)

# %%
df.melt(id_vars='Age').head()
# Out:
#    Age M/F         value
# 0   18   F  16050.666667
# 1   19   F  15351.958333
# 2   20   F  13835.931818
# 3   21   F  14681.027027
# 4   22   F  14366.421053

# %%
df.melt(id_vars='Age', value_name='TotalSeconds', var_name='Sex').head()
# Out:
#    Age Sex  TotalSeconds
# 0   18   F  16050.666667
# 1   19   F  15351.958333
# 2   20   F  13835.931818
# 3   21   F  14681.027027
# 4   22   F  14366.421053

# %%
df = pd.read_csv('../data/marathon_results_2016.csv',
                 index_col='Bib',
                 usecols=['Bib','40K','Half','Pace','Age','M/F','Country','State','City'])

df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)

df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))

df = df.pivot_table(index="Age",columns="M/F",values=["HalfSeconds","TotalSeconds"])
df.head()
# Out:
#      HalfSeconds               TotalSeconds
# M/F            F            M             F             M
# Age
# 18   7999.888889  7078.538462  16050.666667  14554.615385
# 19   7473.666667  5817.764706  15351.958333  12156.529412
# 20   6871.045455  5716.800000  13835.931818  12111.100000
# 21   7148.554054  5929.627907  14681.027027  12408.360465
# 22   7091.097744  5751.000000  14366.421053  11872.666667

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#     Age  HalfSeconds               TotalSeconds
# M/F                F            M             F             M
# 0    18  7999.888889  7078.538462  16050.666667  14554.615385
# 1    19  7473.666667  5817.764706  15351.958333  12156.529412
# 2    20  6871.045455  5716.800000  13835.931818  12111.100000
# 3    21  7148.554054  5929.627907  14681.027027  12408.360465
# 4    22  7091.097744  5751.000000  14366.421053  11872.666667

# %%
df.melt(id_vars='Age', value_vars=['HalfSeconds', 'TotalSeconds']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-9cbb8ad4c04d> in <module>
# ----> 1 df.melt(id_vars='Age', value_vars=['HalfSeconds', 'TotalSeconds']).head()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    7171             value_name=value_name,
#    7172             col_level=col_level,
# -> 7173             ignore_index=ignore_index,
#    7174         )
#    7175
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     120     mdata = {}
#     121     for col in id_vars:
# --> 122         id_data = frame.pop(col)
#     123         if is_extension_array_dtype(id_data):
#     124             id_data = cast("Series", concat([id_data] * K, ignore_index=True))
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in pop(self, item)
#    4369         3  monkey        NaN
#    4370         """
# -> 4371         return super().pop(item=item)
#    4372
#    4373     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2903         if is_single_key:
#    2904             if self.columns.nlevels > 1:
# -> 2905                 return self._getitem_multilevel(key)
#    2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2953     def _getitem_multilevel(self, key):
#    2954         # self.columns is a MultiIndex
# -> 2955         loc = self.columns.get_loc(key)
#    2956         if isinstance(loc, (slice, np.ndarray)):
#    2957             new_columns = self.columns[loc]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2702
#    2703         if not isinstance(key, tuple):
# -> 2704             loc = self._get_level_indexer(key, level=0)
#    2705             return _maybe_to_slice(loc)
#    2706
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2981             if i == j:
#    2982                 # The label is present in self.levels[level] but unused:
# -> 2983                 raise KeyError(key)
#    2984             return slice(i, j)
#    2985
#
# KeyError: 'Age'

# %%
df.melt(id_vars='Age', value_vars=['HalfSeconds', 'TotalSeconds'], value_name='Time', ).head()
#df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-363f32d6c332> in <module>
# ----> 1 df.melt(id_vars='Age', value_vars=['HalfSeconds', 'TotalSeconds'], value_name='Time', ).head()
#       2 #df.head()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    7171             value_name=value_name,
#    7172             col_level=col_level,
# -> 7173             ignore_index=ignore_index,
#    7174         )
#    7175
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     120     mdata = {}
#     121     for col in id_vars:
# --> 122         id_data = frame.pop(col)
#     123         if is_extension_array_dtype(id_data):
#     124             id_data = cast("Series", concat([id_data] * K, ignore_index=True))
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in pop(self, item)
#    4369         3  monkey        NaN
#    4370         """
# -> 4371         return super().pop(item=item)
#    4372
#    4373     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2903         if is_single_key:
#    2904             if self.columns.nlevels > 1:
# -> 2905                 return self._getitem_multilevel(key)
#    2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2953     def _getitem_multilevel(self, key):
#    2954         # self.columns is a MultiIndex
# -> 2955         loc = self.columns.get_loc(key)
#    2956         if isinstance(loc, (slice, np.ndarray)):
#    2957             new_columns = self.columns[loc]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2702
#    2703         if not isinstance(key, tuple):
# -> 2704             loc = self._get_level_indexer(key, level=0)
#    2705             return _maybe_to_slice(loc)
#    2706
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2981             if i == j:
#    2982                 # The label is present in self.levels[level] but unused:
# -> 2983                 raise KeyError(key)
#    2984             return slice(i, j)
#    2985
#
# KeyError: 'Age'
